# %%
# !pip install stackview
from skimage.io import imread
from stackview import imshow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.7 MB/s eta 0:00:00
# ...

# %%
image2 = imread("https://github.com/haesleinhuepf/BioImageAnalysisNotebooks/raw/main/data/blobs.tif")

# %%
image.shape
# Out:
# (254, 256)

# %%
imshow(image)

# %%
cropped_image1 = image[0:128]
imshow(cropped_image1)

# %%
cropped_image2 = image[0:128, 128:]
imshow(cropped_image2)

# %%
sampled_image = image[::5, ::5]
imshow(sampled_image)

# %%
flipped_image = image[:, ::-1]
imshow(flipped_image)

# %%
image2 = imread("https://github.com/haesleinhuepf/BioImageAnalysisNotebooks/raw/main/data/banana0020.tif")

# %%
imshow(image2)

# %%
image2.shape
# Out:
# (384, 384)

# %%
cropped_image2 = image2[150:300, 50:200]
imshow(cropped_image2)
